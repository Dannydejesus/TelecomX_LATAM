# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannydejesus/TelecomX_LATAM/blob/main/TelecomX_LATAM_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import json

# %%
df = pd.read_json('/content/TelecomX_Data.json')
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
# Lista de columnas con datos anidados
columnas_a_normalizar = ['customer', 'phone', 'internet', 'account']

# Normalizar cada columna sin perder registros
for columna in columnas_a_normalizar:
    if columna in df.columns:
        datos_normalizados = pd.json_normalize(df[columna])
        df = df.drop(columns=[columna]).reset_index(drop=True).join(datos_normalizados)

# %%
data_normalizada = df
data_normalizada.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# ...

# %% [markdown]
# #🔧 Transformación

# %%
data_normalizada.sample(6)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 2522  3521-MNKLV    No    Male              0      No         No      24
# 3457  4795-UXVCJ    No    Male              0      No         No      26
# 648   0925-VYDLG   Yes  Female              0      No         No       3
# 1724  2452-MRMZF    No  Female              1     Yes         No      72
# 4599  6303-APKJD          Male              1     Yes         No      57
# 2932  4077-HWUYD    No    Male              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 2522          Yes            No             DSL  ...                   No
# 3457          Yes            No              No  ...  No internet service
# 648           Yes           Yes     Fiber optic  ...                   No
# 1724          Yes           Yes              No  ...  No internet service
# 4599          Yes           Yes     Fiber optic  ...                  Yes
# ...

# %%
data_normalizada['Churn'] = data_normalizada['Churn'].replace('', 'no')
data_normalizada['Churn'] = data_normalizada['Churn'].replace('no', 'No')

columnas_binarias = ["Churn", "Partner", "Dependents", "PhoneService", "PaperlessBilling"]
data_normalizada[columnas_binarias] = data_normalizada[columnas_binarias].replace({"Yes": 1, "No": 0}).astype('int8')

columnas_categoricas = ['gender', 'InternetService', 'Contract', 'PaymentMethod']
data_normalizada[columnas_categoricas] = data_normalizada[columnas_categoricas].astype('category')

columnas_servicios = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                'TechSupport', 'StreamingTV', 'StreamingMovies']
data_normalizada[columnas_servicios] = data_normalizada[columnas_servicios].replace({
    'No internet service': 'No',
    'No': 0,
    'Yes': 1
}).astype('int8', errors='ignore')

data_normalizada['MultipleLines'] = data_normalizada['MultipleLines'].replace({
    'No phone service': 'No',
    'No': 0,
    'Yes': 1
}).astype('int8', errors='ignore')

data_normalizada['SeniorCitizen'] = data_normalizada['SeniorCitizen'].astype('int8')
data_normalizada['Charges.Total'] = pd.to_numeric(data_normalizada['Charges.Total'], errors='coerce')
data_normalizada['Charges.Total'] = data_normalizada['Charges.Total'].fillna(data_normalizada['tenure'] * data_normalizada['Charges.Monthly'])
# crear la columna Cuentas_Diarias.
data_normalizada['Cuentas_Diarias'] = (data_normalizada['Charges.Monthly'] * 12 / 365).round(2)
# Out:
# <ipython-input-71-911080918360>:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_normalizada[columnas_servicios] = data_normalizada[columnas_servicios].replace({

# %%
data_normalizada.head()
# Out:
#    customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  0002-ORFBO      0  Female              0        1           1       9
# 1  0003-MKNFE      0    Male              0        0           0       9
# 2  0004-TLHLJ      1    Male              0        0           0       4
# 3  0011-IGKFF      1    Male              1        1           0      13
# 4  0013-EXCHZ      1  Female              1        1           0       3
#
#    PhoneService  MultipleLines InternetService  ...  DeviceProtection  \
# 0             1              0             DSL  ...                 0
# 1             1              1             DSL  ...                 0
# 2             1              0     Fiber optic  ...                 1
# 3             1              0     Fiber optic  ...                 1
# 4             1              0     Fiber optic  ...                 0
#
#    TechSupport  StreamingTV  StreamingMovies        Contract  \
# ...

# %%
data_normalizada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   int8
#  2   gender            7267 non-null   category
#  3   SeniorCitizen     7267 non-null   int8
#  4   Partner           7267 non-null   int8
#  5   Dependents        7267 non-null   int8
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   int8
#  8   MultipleLines     7267 non-null   int8
#  9   InternetService   7267 non-null   category
#  10  OnlineSecurity    7267 non-null   int8
#  11  OnlineBackup      7267 non-null   int8
#  12  DeviceProtection  7267 non-null   int8
#  13  TechSupport       7267 non-null   int8
#  14  StreamingTV       7267 non-null   int8
#  15  StreamingMovies   7267 non-null   int8
# ...

# %%
data_normalizada.sample(5)
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 5300  7242-EDTYC      0    Male              0        0           1      44
# 4374  5995-WWKKG      0  Female              0        0           0      37
# 4100  5619-XZZKR      0    Male              0        0           0       4
# 5792  7921-LMDFQ      0    Male              1        0           0      51
# 1812  2581-VKIRT      0  Female              0        1           1      59
#
#       PhoneService MultipleLines InternetService  ... DeviceProtection  \
# 5300             1             0              No  ...               No
# 4374             1             0              No  ...               No
# 4100             1             0              No  ...               No
# 5792             1             0     Fiber optic  ...                1
# 1812             1             1             DSL  ...                0
#
#      TechSupport StreamingTV StreamingMovies  Contract PaperlessBilling  \
# ...

# %%
# Diccionario de traducción de nombres de columnas
traducciones = {
    'customerID': 'ID_Cliente',
    'Churn': 'Evasion',
    'gender': 'Genero',
    'SeniorCitizen': 'Ciudadano_Mayor',
    'Partner': 'Pareja',
    'Dependents': 'Dependientes',
    'tenure': 'Antiguedad_Meses',
    'PhoneService': 'Servicio_Telefonico',
    'MultipleLines': 'Lineas_Multiples',
    'InternetService': 'Servicio_Internet',
    'OnlineSecurity': 'Seguridad_En_Linea',
    'OnlineBackup': 'Respaldo_En_Linea',
    'DeviceProtection': 'Proteccion_Dispositivo',
    'TechSupport': 'Soporte_Tecnico',
    'StreamingTV': 'TV_Streaming',
    'StreamingMovies': 'Peliculas_Streaming',
    'Contract': 'Tipo_Contrato',
    'PaperlessBilling': 'Facturacion_Digital',
    'PaymentMethod': 'Metodo_Pago',
    'Charges.Monthly': 'Cargos_Mensuales',
    'Charges.Total': 'Cargos_Totales',
    'Cuentas_Diarias': 'Cuentas_Diarias'
}

# Aplicar las traducciones
data_normalizada = data_normalizada.rename(columns=traducciones)

# Verificar resultados
print("Columnas traducidas:")
print(data_normalizada.columns.tolist())
# Out:
# Columnas traducidas:
# ['ID_Cliente', 'Evasion', 'Genero', 'Ciudadano_Mayor', 'Pareja', 'Dependientes', 'Antiguedad_Meses', 'Servicio_Telefonico', 'Lineas_Multiples', 'Servicio_Internet', 'Seguridad_En_Linea', 'Respaldo_En_Linea', 'Proteccion_Dispositivo', 'Soporte_Tecnico', 'TV_Streaming', 'Peliculas_Streaming', 'Tipo_Contrato', 'Facturacion_Digital', 'Metodo_Pago', 'Cargos_Mensuales', 'Cargos_Totales', 'Cuentas_Diarias']

# %%
data_normalizada.head()
# Out:
#    ID_Cliente  Evasion  Genero  Ciudadano_Mayor  Pareja  Dependientes  \
# 0  0002-ORFBO        0  Female                0       1             1
# 1  0003-MKNFE        0    Male                0       0             0
# 2  0004-TLHLJ        1    Male                0       0             0
# 3  0011-IGKFF        1    Male                1       1             0
# 4  0013-EXCHZ        1  Female                1       1             0
#
#    Antiguedad_Meses  Servicio_Telefonico Lineas_Multiples Servicio_Internet  \
# 0                 9                    1                0               DSL
# 1                 9                    1                1               DSL
# 2                 4                    1                0       Fiber optic
# 3                13                    1                0       Fiber optic
# 4                 3                    1                0       Fiber optic
#
#    ... Proteccion_Dispositivo Soporte_Tecnico TV_Streaming  \
# ...

# %%
data_normalizada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID_Cliente              7267 non-null   object
#  1   Evasion                 7267 non-null   int8
#  2   Genero                  7267 non-null   category
#  3   Ciudadano_Mayor         7267 non-null   int8
#  4   Pareja                  7267 non-null   int8
#  5   Dependientes            7267 non-null   int8
#  6   Antiguedad_Meses        7267 non-null   int64
#  7   Servicio_Telefonico     7267 non-null   int8
#  8   Lineas_Multiples        7267 non-null   object
#  9   Servicio_Internet       7267 non-null   category
#  10  Seguridad_En_Linea      7267 non-null   object
#  11  Respaldo_En_Linea       7267 non-null   object
#  12  Proteccion_Dispositivo  7267 non-null   object
#  13  Soporte_Tecnico         7267 non-null   object
# ...

# %%
data_normalizada.to_parquet('TelecomX_optimizada.parquet')

# %% [markdown]
# #📊 Carga y análisis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_parquet('/content/TelecomX_optimizada.parquet')
data.head()
# Out:
#    ID_Cliente  Evasion  Genero  Ciudadano_Mayor  Pareja  Dependientes  \
# 0  0002-ORFBO        0  Female                0       1             1
# 1  0003-MKNFE        0    Male                0       0             0
# 2  0004-TLHLJ        1    Male                0       0             0
# 3  0011-IGKFF        1    Male                1       1             0
# 4  0013-EXCHZ        1  Female                1       1             0
#
#    Antiguedad_Meses  Servicio_Telefonico  Lineas_Multiples Servicio_Internet  \
# 0                 9                    1                 0               DSL
# 1                 9                    1                 1               DSL
# 2                 4                    1                 0       Fiber optic
# 3                13                    1                 0       Fiber optic
# 4                 3                    1                 0       Fiber optic
#
#    ...  Proteccion_Dispositivo  Soporte_Tecnico  TV_Streaming  \
# ...

# %% [markdown]
# #📄Informe final
